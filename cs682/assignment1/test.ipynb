# %%
import numpy as np
x=np.arange(0,6,1).reshape(2,3)
print(x)
np.add.at(x.T,[0,0,1],1)
print(x)
np.argmax(x,axis=1)
lrs = [1e-7, 5e-5,1e-4]
regs = [2.5e4, 5e4,500]
a=(regs[1]-regs[0]/regs[2])
b=((lrs[1]-lrs[0])/lrs[2])
print(a*b*1000)
lrs = [1e-7, 5e-5,1e-5]
regs = [0.25,1,0.25]
print(np.arange(1,2,1))
random_float_number = np.random.uniform(49.5, 99.5,size=100).tolist()
print(random_float_number)
for rg in np.arange(regs[0],regs[1],regs[2]).tolist():
    print(rg)
# Out:
# [[0 1 2]
#  [3 4 5]]
# [[2 2 2]
#  [5 5 5]]
# 24925050.0
# [1]
# ...
